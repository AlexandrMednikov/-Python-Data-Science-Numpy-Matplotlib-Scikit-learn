# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pylab import rcParams

rcParams['figure.figsize'] = 4, 4 # только для удобства

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
#Задание 1
x = [1, 2, 3, 4, 5, 6, 7]
y = [3.5, 3.8, 4.2, 4.5, 5, 5.5, 7.]
fig, ax = plt.subplots(1, 2)
fig.set_size_inches(8, 4)
ax1, ax2 =ax.flatten()
ax1.plot(x, y)
ax2.scatter(x, y)

# %%
#Задание 2
t = np.linspace(0, 10, 51)
f = np.cos(t)
plt.plot(t, f, color='g')
plt.axis([0.5, 9.5, -2.5, 2.5])
plt.title('График f(t)')
plt.xlabel("Значения f")
plt.ylabel("Значения t")
# Out:
# Text(0, 0.5, 'Значения t')

# %%
#Задание 3
x = np.linspace(-3, 3, 51)
y1 = x**2
y2 = 2 * x + 0.5
y3 = -3 * x - 1.5
y4 = np.sin(x)

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)
ax1, ax2, ax3, ax4 = ax.flatten()
ax1.plot(x, y1)
ax1.set_title('График y1')
ax1.set_xlim([-5, 5])
ax2.plot(x, y2)
ax2.set_title('График y2')
ax3.plot(x, y3)
ax3.set_title('График y3')
ax4.plot(x, y4)
ax4.set_title('График y4')
fig.set_size_inches(8, 6)
plt.subplots_adjust(wspace=0.3, hspace=0.3)

# %%
#Задание 4
from matplotlib import style
plt.style.use('fivethirtyeight')
df = pd.read_csv("creditcard.csv")
dfcountClass = df['Class'].value_counts()
df['Class'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
df['Class'].value_counts().plot(kind='bar')
plt.yscale('log')

# %%
v1_where_class0 = df.set_index('Class')['V1'].filter(like='1', axis=0).reset_index().drop('Class', axis=1)
v1_where_class1 = df.set_index('Class')['V1'].filter(like='0', axis=0).reset_index().drop('Class', axis=1)
plt.hist(v1_where_class0['V1'], density = True, bins=20, alpha=0.5, orientation="horizontal", color='b', edgecolor='black')
plt.hist(v1_where_class1['V1'], density = True, bins=20, alpha=0.5, orientation="horizontal", color='r', edgecolor='black')
plt.xlabel('V1')
plt.legend(labels=['Class 0', 'Class 1'])
